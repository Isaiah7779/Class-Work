# %%
df.dropna(inplace=True)

# %%
import pandas as pd
File="C:/Users/Dell/Downloads/business-employment-data-june-2023-quarter/tryout1.csv"
df=pd.read_csv(File)
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21797    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21798    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21799    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21800    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21801    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
print(df.isnull().sum())
# Out:
# Series_reference        0
# Period                  0
# Data_value           2839
# Suppressed          18963
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4      21802
# Series_title_5      21802
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15724\820435583.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.ffill()
df.bfill()
df.interpolate(method='linear', inplace=True)
df['column_name_missing']=df['Series_reference '].astype(int)
