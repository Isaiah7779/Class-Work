# %%
from numpy.random import normal
import matplotlib.pyplot as plt

# %%
dataset = normal(size=1000)

# %%
plt.hist(dataset,bins=25)
# Out:
# (array([  1.,   1.,   2.,  17.,   7.,  19.,  21.,  43.,  53.,  75., 101.,
#          96.,  97., 103.,  99.,  69.,  63.,  41.,  37.,  20.,  19.,   5.,
#           3.,   5.,   3.]),
#  array([-3.31550267, -3.05574764, -2.79599261, -2.53623757, -2.27648254,
#         -2.01672751, -1.75697247, -1.49721744, -1.23746241, -0.97770737,
#         -0.71795234, -0.45819731, -0.19844227,  0.06131276,  0.32106779,
#          0.58082283,  0.84057786,  1.10033289,  1.36008793,  1.61984296,
#          1.87959799,  2.13935302,  2.39910806,  2.65886309,  2.91861812,
#          3.17837316]),
#  <BarContainer object of 25 artists>)

# %%
plt.hist(dataset,bins=5)
# Out:
# (array([ 28., 211., 496., 230.,  35.]),
#  array([-3.31550267, -2.01672751, -0.71795234,  0.58082283,  1.87959799,
#          3.17837316]),
#  <BarContainer object of 5 artists>)

# %%
from numpy import hstack

# %%
dataset1 = normal(loc=10,scale=3,size=5000)
dataset2 = normal(loc=20,scale=3,size=10000)

# %%
len(dataset)
# Out:
# 1000

# %%
plt.hist(dataset,bins=50,density=True)
# Out:
# (array([0.00769956, 0.        , 0.        , 0.00769956, 0.        ,
#         0.01539912, 0.05389693, 0.07699562, 0.03079825, 0.02309869,
#         0.06929606, 0.07699562, 0.0615965 , 0.10009431, 0.15399124,
#         0.17708993, 0.14629168, 0.26178511, 0.27718423, 0.30028292,
#         0.41577635, 0.36187942, 0.36187942, 0.37727854, 0.40807679,
#         0.33878073, 0.39267767, 0.40037723, 0.46197372, 0.30028292,
#         0.26178511, 0.26948467, 0.23868642, 0.24638599, 0.15399124,
#         0.1616908 , 0.1616908 , 0.12319299, 0.06929606, 0.08469518,
#         0.08469518, 0.0615965 , 0.02309869, 0.01539912, 0.00769956,
#         0.01539912, 0.01539912, 0.02309869, 0.00769956, 0.01539912]),
#  array([-3.31550267, -3.18562516, -3.05574764, -2.92587012, -2.79599261,
#         -2.66611509, -2.53623757, -2.40636006, -2.27648254, -2.14660502,
#         -2.01672751, -1.88684999, -1.75697247, -1.62709496, -1.49721744,
# ...

# %%
plt.hist(dataset, bins=5)
# Out:
# (array([ 28., 211., 496., 230.,  35.]),
#  array([-3.31550267, -2.01672751, -0.71795234,  0.58082283,  1.87959799,
#          3.17837316]),
#  <BarContainer object of 5 artists>)

# %%
dataset = hstack((dataset1, dataset2))

# %%
len(dataset)
# Out:
# 15000

# %%
plt.hist(dataset,bins=50,density=True)
# Out:
# (array([0.00043094, 0.00096962, 0.0015083 , 0.00172378, 0.00237019,
#         0.00441717, 0.00754152, 0.01142001, 0.01432888, 0.01928474,
#         0.02585663, 0.03210532, 0.03318268, 0.03910815, 0.04471042,
#         0.04072419, 0.04460269, 0.04234023, 0.04018551, 0.03749211,
#         0.03469098, 0.03016607, 0.02833456, 0.02941192, 0.03706117,
#         0.04147834, 0.05408345, 0.06496478, 0.07142894, 0.07681574,
#         0.08295669, 0.08974405, 0.08985179, 0.07810857, 0.07326045,
#         0.06841233, 0.05850063, 0.04309438, 0.03943136, 0.02510248,
#         0.01971568, 0.01368247, 0.00872661, 0.0053868 , 0.00290887,
#         0.00237019, 0.00075415, 0.00086189, 0.00010774, 0.00032321]),
#  array([ 0.29146027,  0.91025706,  1.52905385,  2.14785065,  2.76664744,
#          3.38544423,  4.00424102,  4.62303781,  5.24183461,  5.8606314 ,
#          6.47942819,  7.09822498,  7.71702178,  8.33581857,  8.95461536,
# ...
