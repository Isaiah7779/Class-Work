# %%
import pandas as pd
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")

# %%
df.head()
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
# 2     93770          62834            30936   488  ...
# 3     86236          56301            29935    18  ...
# 4    261724         163333            98391   556  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB

# %%
df.isnull()
# Out:
#      District code  State name  District name  Population   Male  Female  \
# 0            False       False          False       False  False   False
# 1            False       False          False       False  False   False
# 2            False       False          False       False  False   False
# 3            False       False          False       False  False   False
# 4            False       False          False       False  False   False
# ..             ...         ...            ...         ...    ...     ...
# 635          False       False          False       False  False   False
# 636          False       False          False       False  False   False
# 637          False       False          False       False  False   False
# 638          False       False          False       False  False   False
# 639          False       False          False       False  False   False
#
#      Literate  Male_Literate  Female_Literate     SC  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# District code                    0
# State name                       0
# District name                    0
# Population                       0
# Male                             0
#                                 ..
# Power_Parity_Rs_330000_425000    0
# Power_Parity_Rs_425000_545000    0
# Power_Parity_Rs_330000_545000    0
# Power_Parity_Above_Rs_545000     0
# Total_Power_Parity               0
# Length: 118, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
row_to_display=df.iloc[8]
print(df.head(5))
print(df.tail(5))
print(df.shape)
print(df.info())
print(df.index)
print(df.columns)
print(df.describe())
rd = reduce(lambda x,y:x*y, df["Population"])
print(df.keys())
df.pivot(columns ='State name')
df.melt()

sq=df["Literate"].map
print(df.isnull().sum())

m_df1=df['Male'].mean()
print(m_df1)

m_df2=df['Female'].mean()
print(m_df1)

max_df1=df['Male'].max()
print(max_df1)

max_df2=df['Female'].max()
print(max_df2)

min_df1=df['Male'].min()
print(min_df1)

min_df2=df['Female'].min()
of = df.groupby('District name')["District name"].count()
print(min_df2)
print(rd)
print(sq)
print(df)
print(row_to_display)
print(of)
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
# 2     93770          62834            30936   488  ...
# 3     86236          56301            29935    18  ...
# 4    261724         163333            98391   556  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# ...

# %%
k=df.isnull()
k

# %%
import seaborn as sns 
import pandas as pd
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <Axes: >

# %%
df.head(5)
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
# 2     93770          62834            30936   488  ...
# 3     86236          56301            29935    18  ...
# 4    261724         163333            98391   556  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# ...

# %%
df.tail()
# Out:
#      District code                   State name              District name  \
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Male_Literate  Female_Literate  \
# 635       41816   19143   22673     36470          16610            19860
# 636      200222   97809  102413    154916          79903            75013
# 637       36842   20727   16115     25332          15397             9935
# 638      105597   54861   50736     78683          43186            35497
# 639      238142  127283  110859    190266         105794            84472
#
# ...

# %%
print(df.shape)
# Out:
# (640, 118)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=640, step=1)

# %%
df.columns
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity'],
#       dtype='object', length=118)

# %%
df['State name'] = df['District name'].str.strip()
df['State name']
# Out:
# 0                        Kupwara
# 1                         Badgam
# 2                    Leh(Ladakh)
# 3                         Kargil
# 4                          Punch
#                  ...
# 635                         Mahe
# 636                     Karaikal
# 637                     Nicobars
# 638    North  AND Middle Andaman
# 639                South Andaman
# Name: State name, Length: 640, dtype: object

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
df["District name"] = scaler.fit_transform(df[["Marginal_Workers"]])
df["District name"]
# Out:
# 0     -0.532401
# 1     -0.679006
# 2     -1.104510
# 3     -1.071878
# 4     -0.644374
#          ...
# 635   -1.213042
# 636   -1.156921
# 637   -1.173211
# 638   -1.172772
# 639   -1.146098
# Name: District name, Length: 640, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
df['Male'] = imputer.fit_transform(df[['Male']])
df['Male']
# Out:
# 0      474190.0
# 1      398041.0
# 2       78971.0
# 3       77785.0
# 4      251899.0
#          ...
# 635     19143.0
# 636     97809.0
# 637     20727.0
# 638     54861.0
# 639    127283.0
# Name: Male, Length: 640, dtype: float64

# %%
print(df.describe())
# Out:
#        District code  District name    Population          Male        Female  \
# count     640.000000   6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000   4.440892e-17  1.891961e+06  9.738598e+05  9.181011e+05
# std       184.896367   1.000782e+00  1.544380e+06  8.007785e+05  7.449864e+05
# min         1.000000  -1.215454e+00  8.004000e+03  4.414000e+03  3.590000e+03
# 25%       160.750000  -6.934000e-01  8.178610e+05  4.171682e+05  4.017458e+05
# 50%       320.500000  -2.569235e-01  1.557367e+06  7.986815e+05  7.589200e+05
# 75%       480.250000   4.706570e-01  2.583551e+06  1.338604e+06  1.264277e+06
# max       640.000000   5.324088e+00  1.106015e+07  5.865078e+06  5.195070e+06
#
#            Literate  Male_Literate  Female_Literate            SC  \
# count  6.400000e+02   6.400000e+02     6.400000e+02  6.400000e+02
# mean   1.193186e+06   6.793182e+05     5.138675e+05  3.146537e+05
# std    1.068583e+06   5.924144e+05     4.801816e+05  3.129818e+05
# ...

# %%
rd = reduce(lambda x,y:x*y, df["Others_Religions"])
print(rd)
# Out:
# 0

# %%
print(df.keys())
# Out:
# Index(['District code', 'State name', 'District name', 'Population', 'Male',
#        'Female', 'Literate', 'Male_Literate', 'Female_Literate', 'SC',
#        ...
#        'Power_Parity_Rs_90000_150000', 'Power_Parity_Rs_45000_150000',
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity'],
#       dtype='object', length=118)

# %%
df.pivot(columns ='Male')
df
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
df.melt()
# Out:
#                  variable  value
# 0           District code      1
# 1           District code      2
# 2           District code      3
# 3           District code      4
# 4           District code      5
# ...                   ...    ...
# 75515  Total_Power_Parity  10027
# 75516  Total_Power_Parity   4890
# 75517  Total_Power_Parity   3151
# 75518  Total_Power_Parity   3151
# 75519  Total_Power_Parity   5782
#
# [75520 rows x 2 columns]

# %%
def greater_than(n):
    return n>33
It=list(filter(lambda x:greater_than(x), df["Christians"]))
print(It)
# Out:
# [1700, 1489, 658, 604, 958, 983, 1828, 1497, 572, 2746, 406, 1109, 429, 1449, 460, 472, 414, 277, 1962, 1208, 12104, 2306, 1559, 3023, 212, 1568, 876, 243, 390, 236, 1452, 577, 2025, 485, 176587, 5445, 26016, 14968, 1479, 1698, 16517, 3277, 19358, 1681, 1227, 2474, 917, 5683, 54344, 6095, 2094, 5342, 2406, 622, 8720, 353, 428, 171, 656, 13416, 2161, 1401, 397, 1895, 870, 5091, 6064, 4878, 2583, 3705, 3646, 1943, 1769, 2049, 2261, 1405, 889, 996, 2186, 1945, 873, 732, 734, 301, 701, 9725, 1235, 9743, 932, 14100, 7256, 9123, 15792, 4852, 3527, 18337, 31226, 41880, 2077, 1542, 1901, 958, 1004, 2696, 1576, 688, 602, 945, 439, 12708, 1122, 1912, 6035, 874, 1157, 730, 1284, 1345, 10605, 754, 682, 1978, 759, 830, 22250, 1274, 5665, 1432, 842, 7406, 358, 6523, 6495, 6184, 13157, 9201, 5952, 10582, 1840, 19026, 7366, 4088, 7635, 1350, 3179, 10076, 3370, 1729, 6320, 14822, 3510, 4630, 7502, 6579, 5822, 3574, 20493, 3634, 3137, 1263, 1362, 1004, 1300, 15751, 1148, 7050, 1351, 814, 965, 1367, 69
# ...

# %%
sq=df["Population"].map
print(sq)
# Out:
# <bound method Series.map of 0      870354
# 1      753745
# 2      133487
# 3      140802
# 4      476835
#         ...
# 635     41816
# 636    200222
# 637     36842
# 638    105597
# 639    238142
# Name: Population, Length: 640, dtype: int64>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
plt.bar(df['State name'], df['Population'])
plt.xlabel('States')
plt.ylabel('Popuation')
plt.title('Population of each state')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
plt.plot(df['State name'], df['Population'])
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Line Plot')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
event_a_column = 'State name'
event_b_column = 'Population'
conditional_probabilities = df.groupby(event_a_column)[event_b_column].mean()
plt.figure(figsize=(8, 6))  # Set the figure size
sns.barplot(x=conditional_probabilities.index, y=conditional_probabilities.values)
plt.xlabel(event_a_column)
plt.ylabel(f'P({event_b_column} | {event_a_column})')
plt.title('Conditional Probability Chart Example')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility if needed
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
plt.scatter(df['State name'], df['Population'])
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Scatter')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
df_column = 'Population'
plt.figure(figsize=(8, 6))  # Set the figure size
sns.boxplot(x=df[df_column])
plt.xlabel(df_column)
plt.title('Boxplot Example')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
df_column = 'Population'
plt.figure(figsize=(8, 6))  # Set the figure size
sns.histplot(df[df_column], bins=10, kde=True, color='black')
plt.xlabel(df_column)
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
data_column = 'Population'
plt.figure(figsize=(8, 6))  # Set the figure size
sns.kdeplot(data=df[data_column], fill=True, color='red')
plt.xlabel(data_column)
plt.ylabel('Density')
plt.title('Density Plot Example')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
categories = df['State name']
values = df['Population']

# Step 3: Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=140)

# Step 4: Customize the chart (if needed)
plt.title('Pie Chart Example')  # Add a title

# Step 5: Display or save the chart
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.
plt.show()
# OR save the chart to a file
# plt.savefig('pie_chart.png')

# Step 6: Close the chart (if necessary)
plt.close()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
sns.pairplot(df, diag_kind='auto')
plt.show()

# %%
import pandas as pd
df=pd.read_csv"C:/Users/Dell/Downloads/india-districts-census-2011.csv")
import matplotlib.pyplot as plt
data_to_plot = df['State name']
plt.hist(data_to_plot, bins=10)  # You can adjust the number of bins
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Histogram of Column Name ')
plt.show()

# %%
import pandas as pd
df = pd.read_csv("C:/Users/Dell/Downloads/india-districts-census-2011.csv")
import seaborn as sns
import matplotlib.pyplot as plt
x = 'State name'
y = 'Population'
sns.countplot(data=df, x=x, hue=y)
plt.xlabel('X-axis label')
plt.ylabel('Count')
plt.title('Grouped Bar Chart)
plt.show()
