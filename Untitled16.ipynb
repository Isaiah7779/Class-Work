# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image of Madara Uchiha
image_path = 'r.jpeg'  # Replace with the path to your image file
img = mpimg.imread("C:/Users/Dell/Desktop/r.jpeg")

plt.figure(figsize=(8, 8))
plt.imshow(img)
plt.axis('off')  # Turn off axis labels and ticks
plt.show()
